# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilquil/AI/blob/main/Airline_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
d=pd.read_csv("/content/airlines_flights_data.csv")

# %%
d
# Out:
#          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# ...

# %%
d.describe()
# Out:
#                index       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
df=pd.DataFrame(d)

# %%
dn=pd.DataFrame()
dc=pd.DataFrame()
for i in df.columns:
  if d[i].dtype=='int64' or d[i].dtype=='float64':
    dn[i]=d[i]
  if d[i].dtype=='object':
    dc[i]=d[i]

# %%
dc
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class
# 0                Mumbai   Economy
# ...

# %%
dn
# Out:
#          index  duration  days_left  price
# 0            0      2.17          1   5953
# 1            1      2.33          1   5953
# 2            2      2.17          1   5956
# 3            3      2.25          1   5955
# 4            4      2.33          1   5955
# ...        ...       ...        ...    ...
# 300148  300148     10.08         49  69265
# 300149  300149     10.42         49  77105
# 300150  300150     13.83         49  79099
# 300151  300151     10.00         49  81585
# 300152  300152     10.08         49  81585
#
# [300153 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in dc.columns:
  dc[i]=LabelEncoder().fit_transform(dc[i])

# %%
dc
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# 0             4    1408            2               2      2             5
# 1             4    1387            2               1      2             4
# 2             0    1213            2               1      2             1
# 3             5    1559            2               4      2             0
# 4             5    1549            2               4      2             4
# ...         ...     ...          ...             ...    ...           ...
# 300148        5    1477            1               4      0             2
# 300149        5    1481            1               0      0             5
# 300150        5    1486            1               1      0             5
# 300151        5    1483            1               1      0             2
# 300152        5    1477            1               4      0             2
#
#         destination_city  class
# 0                      5      1
# ...

# %%
dm=pd.concat((dn,dc),axis=1)

# %%
dm
# Out:
#          index  duration  days_left  price  airline  flight  source_city  \
# 0            0      2.17          1   5953        4    1408            2
# 1            1      2.33          1   5953        4    1387            2
# 2            2      2.17          1   5956        0    1213            2
# 3            3      2.25          1   5955        5    1559            2
# 4            4      2.33          1   5955        5    1549            2
# ...        ...       ...        ...    ...      ...     ...          ...
# 300148  300148     10.08         49  69265        5    1477            1
# 300149  300149     10.42         49  77105        5    1481            1
# 300150  300150     13.83         49  79099        5    1486            1
# 300151  300151     10.00         49  81585        5    1483            1
# 300152  300152     10.08         49  81585        5    1477            1
#
#         departure_time  stops  arrival_time  destination_city  class
# ...

# %%
dm.drop('index',axis=1,inplace=True)

# %%
dm
# Out:
#         duration  days_left  price  airline  flight  source_city  \
# 0           2.17          1   5953        4    1408            2
# 1           2.33          1   5953        4    1387            2
# 2           2.17          1   5956        0    1213            2
# 3           2.25          1   5955        5    1559            2
# 4           2.33          1   5955        5    1549            2
# ...          ...        ...    ...      ...     ...          ...
# 300148     10.08         49  69265        5    1477            1
# 300149     10.42         49  77105        5    1481            1
# 300150     13.83         49  79099        5    1486            1
# 300151     10.00         49  81585        5    1483            1
# 300152     10.08         49  81585        5    1477            1
#
#         departure_time  stops  arrival_time  destination_city  class
# 0                    2      2             5                 5      1
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=pd.DataFrame()
y=pd.DataFrame()
for i in dm.columns:
  if i=='price':
    y[i]=dm[i]
  else:
    x[i]=dm[i]

# %%
x
# Out:
#         duration  days_left  airline  flight  source_city  departure_time  \
# 0           2.17          1        4    1408            2               2
# 1           2.33          1        4    1387            2               1
# 2           2.17          1        0    1213            2               1
# 3           2.25          1        5    1559            2               4
# 4           2.33          1        5    1549            2               4
# ...          ...        ...      ...     ...          ...             ...
# 300148     10.08         49        5    1477            1               4
# 300149     10.42         49        5    1481            1               0
# 300150     13.83         49        5    1486            1               1
# 300151     10.00         49        5    1483            1               1
# 300152     10.08         49        5    1477            1               4
#
#         stops  arrival_time  destination_city  class
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
print("Mean Squared Error (MSE): ",mean_squared_error(y_test,y_pred))
print("R2 score: ",r2_score(y_test,y_pred))
# Out:
# Mean Squared Error (MSE):  49189755.071329795
# R2 score:  0.9045752733051884
